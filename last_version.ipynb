# %%
import pandas as pd 
import numpy as np
from utills.utills import main_utills

# %%
path='data_start/train.json'
df_finish=main_utills(path)

# %%
df_finish
# Out:
#         target  order_1  order_2  order_21  order_22  order_29  order_30  \
# 0            0      1.0      1.0       NaN       NaN       NaN       NaN
# 1            0      NaN      NaN       NaN       NaN       NaN       NaN
# 2            1      NaN      NaN       1.0       1.0       NaN       NaN
# 3            1      NaN      1.0       1.0       NaN       1.0       1.0
# 4            0      NaN      NaN       NaN       NaN       NaN       NaN
# ...        ...      ...      ...       ...       ...       ...       ...
# 127750       1      NaN      NaN       NaN       NaN       NaN       NaN
# 127751       1      NaN      NaN       NaN       NaN       NaN       NaN
# 127752       0      NaN      NaN       NaN       NaN       NaN       NaN
# 127753       0      NaN      NaN       NaN       NaN       NaN       NaN
# 127754       0      NaN      NaN       1.0       1.0       1.0       NaN
#
#         order_39  order_40  order_20  ...  meta1619  meta1503  meta1365  \
# ...

# %%
df_finish.to_csv('data_my/data.csv', index=False)

# %%
df_finish=pd.read_csv('data_my/data.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df_finish.iloc[:, 1:], df_finish.iloc[:, 0], random_state=12)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
print('accuracy_score:', accuracy_score(y_test, model.predict(X_test)))
# Out:
# accuracy_score: 0.8260120855380569

# %%
model_CBC = CatBoostClassifier()
model_CBC.fit(X_train, y_train)
# Out:
# Learning rate set to 0.072278
# 0:	learn: 0.6696506	total: 29.2ms	remaining: 29.2s
# 1:	learn: 0.6507910	total: 61.4ms	remaining: 30.7s
# 2:	learn: 0.6354673	total: 94.6ms	remaining: 31.4s
# 3:	learn: 0.6209276	total: 124ms	remaining: 30.9s
# 4:	learn: 0.6085388	total: 153ms	remaining: 30.4s
# 5:	learn: 0.5988064	total: 190ms	remaining: 31.5s
# 6:	learn: 0.5890599	total: 230ms	remaining: 32.6s
# 7:	learn: 0.5809813	total: 269ms	remaining: 33.4s
# 8:	learn: 0.5734771	total: 302ms	remaining: 33.3s
# 9:	learn: 0.5668799	total: 337ms	remaining: 33.4s
# 10:	learn: 0.5610189	total: 374ms	remaining: 33.7s
# 11:	learn: 0.5558325	total: 408ms	remaining: 33.6s
# 12:	learn: 0.5507717	total: 442ms	remaining: 33.5s
# 13:	learn: 0.5464300	total: 474ms	remaining: 33.4s
# 14:	learn: 0.5423038	total: 508ms	remaining: 33.4s
# 15:	learn: 0.5380012	total: 538ms	remaining: 33.1s
# 16:	learn: 0.5344497	total: 568ms	remaining: 32.8s
# 17:	learn: 0.5311348	total: 603ms	remaining: 32.9s
# ...

# %%
print('accuracy_score:', accuracy_score(y_test, model_CBC.predict(X_test)))
# Out:
# accuracy_score: 0.8337142678230377

# %%
cross_validate(CatBoostClassifier(), df_finish.iloc[:, 1:], df_finish.iloc[:, 0], cv=5, 
               scoring={'accuracy_score': make_scorer(accuracy_score), 
                        })
# Out:
# Learning rate set to 0.074298
# 0:	learn: 0.6689024	total: 32.9ms	remaining: 32.8s
# 1:	learn: 0.6502985	total: 69ms	remaining: 34.4s
# 2:	learn: 0.6336952	total: 103ms	remaining: 34.3s
# 3:	learn: 0.6194583	total: 143ms	remaining: 35.7s
# 4:	learn: 0.6081133	total: 184ms	remaining: 36.6s
# 5:	learn: 0.5968386	total: 218ms	remaining: 36.1s
# 6:	learn: 0.5866407	total: 251ms	remaining: 35.6s
# 7:	learn: 0.5787879	total: 285ms	remaining: 35.3s
# 8:	learn: 0.5722263	total: 327ms	remaining: 36s
# 9:	learn: 0.5657883	total: 360ms	remaining: 35.6s
# 10:	learn: 0.5600982	total: 397ms	remaining: 35.7s
# 11:	learn: 0.5540704	total: 431ms	remaining: 35.5s
# 12:	learn: 0.5490488	total: 477ms	remaining: 36.2s
# 13:	learn: 0.5443053	total: 516ms	remaining: 36.3s
# 14:	learn: 0.5397346	total: 555ms	remaining: 36.4s
# 15:	learn: 0.5355819	total: 598ms	remaining: 36.8s
# 16:	learn: 0.5319895	total: 634ms	remaining: 36.6s
# 17:	learn: 0.5286583	total: 671ms	remaining: 36.6s
# ...
